# %% [markdown]
# # Using Jupyter Notebooks
# :label:`sec_jupyter`
#
#
# This section describes how to edit and run the code
# in each section of this book
# using the Jupyter Notebook. Make sure you have
# installed Jupyter and downloaded the
# code as described in
# :ref:`chap_installation`.
# If you want to know more about Jupyter see the excellent tutorial in
# their [documentation](https://jupyter.readthedocs.io/en/latest/).
#
#
# ## Editing and Running the Code Locally
#
# Suppose that the local path of the book's code is `xx/yy/d2l-en/`. Use the shell to change the directory to this path (`cd xx/yy/d2l-en`) and run the command `jupyter notebook`. If your browser does not do this automatically, open http://localhost:8888 and you will see the interface of Jupyter and all the folders containing the code of the book, as shown in :numref:`fig_jupyter00`.
#
# ![The folders containing the code of this book.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter00.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter00`
#
#
# You can access the notebook files by clicking on the folder displayed on the webpage.
# They usually have the suffix ".ipynb".
# For the sake of brevity, we create a temporary "test.ipynb" file.
# The content displayed after you click it is
# shown in :numref:`fig_jupyter01`.
# This notebook includes a markdown cell and a code cell. The content in the markdown cell includes "This Is a Title" and "This is text.".
# The code cell contains two lines of Python code.
#
# ![Markdown and code cells in the "text.ipynb" file.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter01.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter01`
#
#
# Double click on the markdown cell to enter edit mode.
# Add a new text string "Hello world." at the end of the cell, as shown in :numref:`fig_jupyter02`.
#
# ![Edit the markdown cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter02.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter02`
#
#
# As demonstrated in :numref:`fig_jupyter03`,
# click "Cell" $\rightarrow$ "Run Cells" in the menu bar to run the edited cell.
#
# ![Run the cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter03.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter03`
#
# After running, the markdown cell is shown in :numref:`fig_jupyter04`.
#
# ![The markdown cell after running.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter04.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter04`
#
#
# Next, click on the code cell. Multiply the elements by 2 after the last line of code, as shown in :numref:`fig_jupyter05`.
#
# ![Edit the code cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter05.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter05`
#
#
# You can also run the cell with a shortcut ("Ctrl + Enter" by default) and obtain the output result from :numref:`fig_jupyter06`.
#
# ![Run the code cell to obtain the output.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter06.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter06`
#
#
# When a notebook contains more cells, we can click "Kernel" $\rightarrow$ "Restart & Run All" in the menu bar to run all the cells in the entire notebook. By clicking "Help" $\rightarrow$ "Edit Keyboard Shortcuts" in the menu bar, you can edit the shortcuts according to your preferences.
#
# ## Advanced Options
#
# Beyond local editing two things are quite important: editing the notebooks in the markdown format and running Jupyter remotely.
# The latter matters when we want to run the code on a faster server.
# The former matters since Jupyter's native ipynb format stores a lot of auxiliary data that is
# irrelevant to the content,
# mostly related to how and where the code is run.
# This is confusing for Git, making
# reviewing contributions very difficult.
# Fortunately there is an alternative---native editing in the markdown format.
#
# ### Markdown Files in Jupyter
#
# If you wish to contribute to the content of this book, you need to modify the
# source file (md file, not ipynb file) on GitHub.
# Using the notedown plugin we
# can modify notebooks in the md format directly in Jupyter.
#
#
# First, install the notedown plugin, run the Jupyter Notebook, and load the plugin:
#
# ```
# pip install d2l-notedown  # You may need to uninstall the original notedown.
# jupyter notebook --NotebookApp.contents_manager_class='notedown.NotedownContentsManager'
# ```
#
# You may also turn on the notedown plugin by default whenever you run the Jupyter Notebook.
# First, generate a Jupyter Notebook configuration file (if it has already been generated, you can skip this step).
#
# ```
# jupyter notebook --generate-config
# ```
#
# Then, add the following line to the end of the Jupyter Notebook configuration file (for Linux or macOS, usually in the path `~/.jupyter/jupyter_notebook_config.py`):
#
# ```
# c.NotebookApp.contents_manager_class = 'notedown.NotedownContentsManager'
# ```
#
# After that, you only need to run the `jupyter notebook` command to turn on the notedown plugin by default.
#
# ### Running Jupyter Notebooks on a Remote Server
#
# Sometimes, you may want to run Jupyter notebooks on a remote server and access it through a browser on your local computer. If Linux or macOS is installed on your local machine (Windows can also support this function through third-party software such as PuTTY), you can use port forwarding:
#
# ```
# ssh myserver -L 8888:localhost:8888
# ```
#
# The above string `myserver` is the address of the remote server.
# Then we can use http://localhost:8888 to access the remote server `myserver` that runs Jupyter notebooks. We will detail on how to run Jupyter notebooks on AWS instances
# later in this appendix.
#
# ### Timing
#
# We can use the `ExecuteTime` plugin to time the execution of each code cell in Jupyter notebooks.
# Use the following commands to install the plugin:
#
# ```
# pip install jupyter_contrib_nbextensions
# jupyter contrib nbextension install --user
# jupyter nbextension enable execute_time/ExecuteTime
# ```
#
# ## Summary
#
# * Using the Jupyter Notebook tool, we can edit, run, and contribute to each section of the book.
# * We can run Jupyter notebooks on remote servers using port forwarding.
#
#
# ## Exercises
#
# 1. Edit and run the code in this book with the Jupyter Notebook on your local machine.
# 1. Edit and run the code in this book with the Jupyter Notebook *remotely* via port forwarding.
# 1. Compare the running time of the operations $\mathbf{A}^\top \mathbf{B}$ and $\mathbf{A} \mathbf{B}$ for two square matrices in $\mathbb{R}^{1024 \times 1024}$. Which one is faster?
#
#
# [Discussions](https://discuss.d2l.ai/t/421)

# %%
import numpy as np

mat=np.random.randint(0,8,(4,4))
mat
# Out:
# array([[4, 6, 0, 7],
#        [5, 4, 2, 2],
#        [5, 3, 7, 6],
#        [6, 6, 1, 4]])

# %%
f={}
def freq(I):
  m=0
  for i in I:
      for j in range(len(i)):
          m=max(i[j],m)
  for k in range(m+1):
    f[k]=len(np.where(I==k)[0])
  return f
freq(mat)
# Out:
# {0: 1, 1: 1, 2: 2, 3: 1, 4: 3, 5: 2, 6: 4, 7: 2}

# %%
p={}
def pdf(f):
  pv=f.values()
  pk=f.keys()
  psum=sum(pv)
  for i,v in zip(pk,pv):
    p[i]=v/psum
  return p
pdf(f)
# Out:
# {0: 0.0625,
#  1: 0.0625,
#  2: 0.125,
#  3: 0.0625,
#  4: 0.1875,
#  5: 0.125,
#  6: 0.25,
#  7: 0.125}

# %%
c={}
def cdf(p):
  cv=p.values()
  ck=p.keys()
  for i,v in zip(ck,cv):
    if i==0:
      c[i]=v
    else:
      c[i]=c[i-1]+v
  return c
cdf(p)
# Out:
# {0: 0.0625, 1: 0.125, 2: 0.25, 3: 0.3125, 4: 0.5, 5: 0.625, 6: 0.875, 7: 1.0}

# %%
r=max(p.keys())
r
# Out:
# 7

# %%
h={}
def hist(c):
  hv=c.values()
  for i,hv in zip(c.keys(),hv):
    h[i]=r*hv
  return h
hist(c)
# Out:
# {0: 0.4375, 1: 0.875, 2: 1.75, 3: 2.1875, 4: 3.5, 5: 4.375, 6: 6.125, 7: 7.0}

# %%
ro={}
def equa(h):
  hv=h.values()
  for i,hv in zip(h.keys(),hv):
    ro[i]=round(hv,0)
  return ro
equa(h)
# Out:
# {0: 0.0, 1: 1.0, 2: 2.0, 3: 2.0, 4: 4.0, 5: 4.0, 6: 6.0, 7: 7.0}

# %%
def histequa(I):
  f=freq(I)
  pdf_values=pdf(f) # Renamed the local variable
  cdf_values=cdf(pdf_values)
  hist_values=hist(cdf_values)
  h1_values=equa(hist_values)
  data={
      "GL":list(f.keys()), # Added "GL" key
      "fl":list(f.values()), # Added "fl" key
      "pdf":list(pdf_values.values()), # Added "pdf" key
      "cdf":list(cdf_values.values()), # Added "cdf" key
      "hist":list(hist_values.values()), # Added "hist" key
      "h1":list(h1_values.values()) # Added "h1" key
  }
  return data

# %%
f={}
def freq(I):
  m=0
  for i in I:
      for j in range(len(i)):
          m=max(i[j],m)
  for k in range(m+1):
    f[k]=len(np.where(I==k)[0])
  return f
freq(mat)
p={}
def pdf(f):
  pv=f.values()
  pk=f.keys()
  psum=sum(pv)
  for i,v in zip(pk,pv):
    p[i]=v/psum
  return p
pdf(f)
c={}
def cdf(p):
  cv=p.values()
  ck=p.keys()
  for i,v in zip(ck,cv):
    if i==0:
      c[i]=v
    else:
      c[i]=c[i-1]+v
  return c
cdf(p)
def hist(CDF):
    HE={}
    m=max(CDF.keys())
    for key,val in zip(CDF.keys(),CDF.values()):
        HE[key]=round(m*val)
    return HE
def histequa(I):
    F=freq(I)#calculating no. of pixels for each value in an image
    PDF=pdf(F)#calculating probability distribution of pixels
    CDF=cdf(PDF)#calculating cumulative distribution of probability values
    HE=hist(CDF)#equalizing histogram values
    data={
        "Gray Scale":F.keys(),
        "No. of pixel":F.values(),
        "PDF":PDF.values(),
        "CDF":CDF.values(),
        "Histogram Equalization" : HE.values()
    }
    df=pd.DataFrame(data)#This is not required to display
    print(df)
    return HE
import cv2
mat=np.random.randint(0,8,(4,4))
print(mat)
HE=histequa(mat)
FE=freq(mat)
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.bar(FE.keys(),FE.values(),color='blue')
plt.title("original histo")
plt.xlabel("gray level")
plt.ylabel("freq")
plt.subplot(1,2,2)
plt.bar(HE.keys(),HE.values(),color='blue')
plt.title("equalised histo")
plt.xlabel("gray level")
plt.ylabel("freq")
plt.tight_layout()
plt.show()
# Out:
# [[1 7 4 6]
#  [7 6 0 3]
#  [3 0 5 1]
#  [4 4 0 2]]
#    Gray Scale  No. of pixel     PDF     CDF  Histogram Equalization
# 0           0             3  0.1875  0.1875                       1
# 1           1             2  0.1250  0.3125                       2
# 2           2             1  0.0625  0.3750                       3
# 3           3             2  0.1250  0.5000                       4
# 4           4             3  0.1875  0.6875                       5
# 5           5             1  0.0625  0.7500                       5
# 6           6             2  0.1250  0.8750                       6
# 7           7             2  0.1250  1.0000                       7

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#Taking the matix by using random function
mat=np.random.randint(0,8,(4,4))
#randint: to generate random integer values.(0,8) is a range. (4,4) no. of rows and cols
#create some duplicates manually
mat[0,3],mat[2,2],mat[1,3]=mat[2,2],mat[3,2],mat[3,3]
print(mat)
HE=histequa(mat)
FE=freq(mat)
plt.suptitle("Histogram Equalization by 23B81A7363")
plt.subplot(1,2,1)
plt.title("Original Histogram")
plt.bar(FE.keys(),FE.values())
plt.subplot(1,2,2)
plt.title("Histogram after equalization")
plt.bar(HE.keys(),HE.values())
# Out:
# [[7 1 0 0]
#  [1 4 4 5]
#  [3 1 3 2]
#  [6 0 3 5]]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipython-input-1935384226.py in <cell line: 0>()
#       9 mat[0,3],mat[2,2],mat[1,3]=mat[2,2],mat[3,2],mat[3,3]
#      10 print(mat)
# ---> 11 HE=histequa(mat)
#      12 FE=freq(mat)
#      13 plt.suptitle("Histogram Equalization by 23B81A7363")
#
# /tmp/ipython-input-4147423745.py in histequa(I)
#       1 def histequa(I):
#       2   f=freq(I)
# ----> 3   pdf=pdf(f)
#       4   cdf=cdf(pdf)
#       5   hist=hist(cdf)
#
# UnboundLocalError: cannot access local variable 'pdf' where it is not associated with a value

# %%
import cv2
img=cv2.imread("pic.jpg")
img1=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
mat=np.asarray(img1)
OH=freq(mat)
HE=histequa(mat)
I=np.copy(img1)
for i in HE.keys():
    I[img1==i]=HE[i]
plt.figure(figsize=(10,10))
plt.suptitle("Histogram Equalization by 23B81A7363")
plt.subplot(2,2,1)
plt.title("Original Image")
plt.imshow(img1,cmap='gray')
plt.subplot(2,2,2)
plt.title("Original Histogram")
plt.bar(OH.keys(),OH.values())
plt.subplot(2,2,3)
plt.title("Image after Histogram Equalization")
plt.imshow(I,cmap='gray')
plt.subplot(2,2,4)
plt.title("Histogram after equalization")
plt.bar(HE.keys(),HE.values())
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipython-input-2008357290.py in <cell line: 0>()
#       4 mat=np.asarray(img1)
#       5 OH=freq(mat)
# ----> 6 HE=histequa(mat)
#       7 I=np.copy(img1)
#       8 for i in HE.keys():
#
# /tmp/ipython-input-1888261102.py in histequa(I)
#       1 def histequa(I):
#       2   f=freq(I)
# ----> 3   pdf=pdf(f)
#       4   cdf=cdf(pdf)
#       5   hist=hist(cdf)
#
# UnboundLocalError: cannot access local variable 'pdf' where it is not associated with a value

# %%
img=cv2.imread("pic.jpg")
img1=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
mat=np.asarray(img1)
OH=freq(mat)
HE=histogramEqualization(mat)
I=np.copy(img1)
for i in HE.keys():
    I[img1==i]=HE[i]
plt.figure(figsize=(10,10))
plt.suptitle("Histogram Equalization by 23B81A7363")
plt.subplot(2,2,1)
plt.title("Original Image")
plt.imshow(img1,cmap='gray')
plt.subplot(2,2,2)
plt.title("Original Histogram")
plt.bar(OH.keys(),OH.values())
plt.subplot(2,2,3)
plt.title("Image after Histogram Equalization")
plt.imshow(I,cmap='gray')
plt.subplot(2,2,4)
plt.title("Histogram after equalization")
plt.bar(HE.keys(),HE.values())
# Out:
#      Gray Scale  No. of pixel       PDF       CDF  Histogram Equalization
# 0             0             0  0.000000  0.000000                       0
# 1             1             0  0.000000  0.000000                       0
# 2             2             0  0.000000  0.000000                       0
# 3             3             1  0.000001  0.000001                       0
# 4             4             5  0.000007  0.000009                       0
# ..          ...           ...       ...       ...                     ...
# 250         250             4  0.000006  0.999985                     254
# 251         251             5  0.000007  0.999993                     254
# 252         252             1  0.000001  0.999994                     254
# 253         253             3  0.000004  0.999999                     254
# 254         254             1  0.000001  1.000000                     254
#
# [255 rows x 5 columns]
# <BarContainer object of 255 artists>

# %%
import cv2
import numpy as np
r=int(input())
c=int(input())
n=np.random.randint(0,8,(r,c))
print(n)
a=int(input("enter the size r kernel"))
b=int(input("enter c kernel"))
n1=np.zeros(((r+a-1),(c+b-1)),dtype='int')
n1[a//2:r+a//2,b//2:c+b//2]=n[::]
print(n1)
for i in range(a//2,r+a//2):
  for j in range(b//2,c+b//2):
    s=0
    for k in range(i-a//2,i+a//2+1):
      for k1 in range(j-b//2,j+b//2+1):
        s=s+n1[k,k1]
    n1[i,j]=np.ceil(s/(a*b))
print("\n",n1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2344728713.py in <cell line: 0>()
#       1 import cv2
#       2 import numpy as np
# ----> 3 r=int(input())
#       4 c=int(input())
#       5 n=np.random.randint(0,8,(r,c))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
def mean(I,r,c,a,b):
  n1=np.copy(I)
  for i in range(r):
    for j in range(c):
      s=0
      for k in range(i-a//2,i+a//2+1):
        for k1 in range(j-b//2,j+b//2+1):
          if(0<=k<r and 0<=k1<c):
            s=s+I[k,k1]
      n1[i,j]=np.ceil(s/(a*b))
  return n1

# %%
def median(I,r,c,a,b):
  n1=np.copy(I)
  ws=a*b
  for i in range(r):
    for j in range(c):
      s=[0]*ws
      p=0
      for k in range(i-a//2,i+a//2+1):
        for k1 in range(j-b//2,j+b//2+1):
          if(0<=k<r and 0<=k1<c):
            s[p]=I[k,k1]
            p+=1
      s.sort()
      if ws%2==0:
        med=np.ceil((s[ws//2])+(s[(ws//2)-1]))/2
      else:
        med=s[ws//2]
      n1[i,j]=med
  return n1

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
i=cv2.imread("pic.jpg")
if i is None:
  print("Error: Could not load image. Please make sure 'pic.jpg' is in the correct directory.")
else:
  i1=cv2.cvtColor(i,cv2.COLOR_BGR2GRAY)
  i1=np.array(i1)
  m,n=i1.shape
  nl=np.random.randint(0,255,(m,n))
  pepper=30
  salt=200
  for i in range(m):
    for j in range(n):
      if nl[i,j]<=pepper:
        nl[i,j]=0
      elif nl[i,j]>=salt:
        nl[i,j]=255
      else:
        nl[i,j]=i1[i,j]
  i2=np.copy(nl)
  i3=np.copy(nl)
  i2=mean(i2,m,n,7,7)
  i3=median(i3,m,n,7,7)
  plt.figure(figsize=(10,10))
  plt.subplot(3,2,1)
  plt.title("original image")
  plt.imshow(nl,cmap='gray')
  plt.axis('off')
  plt.subplot(3,2,2)
  plt.title("mean image")
  plt.imshow(i2,cmap='gray')
  plt.axis('off')
  plt.subplot(3,2,3)
  plt.title("median image")
  plt.imshow(i3,cmap='gray')
  plt.axis('off')

# %%
import numpy as np
import math
import cv2
import matplotlib.pyplot as plt
def padding(I):
    M,N=I.shape
    P=np.zeros((2*M,2*N),dtype=np.float64)
    P[0:M,0:N]=I
    return P
def centering(P):
    M,N=P.shape
    C=np.zeros((M,N),dtype=np.float64)
    for i in range(M):
        for j in range(N):
            C[i,j]=P[i,j]*((-1)**(i+j))
    return C
def create_kernel(size,flag):
    ker=np.zeros((size,size),dtype=np.float64)
    for u in range(size):
        for m in range(size):
            if flag==0:
                ker[u,m]=np.exp(-(2j*math.pi*u*m)/size)
            elif flag==1:
                ker[u,m]=np.exp((2j*math.pi*u*m)/size)
    return ker
def DFT(I):
    M,N=I.shape
    k1=create_kernel(M,0)
    k2=create_kernel(N,0)
    temp=np.matmul(k1,I)
    D=np.matmul(temp,k2)
    return D
def ILPF(D,do):
    M,N=D.shape
    H=np.zeros_like(D)
    cx=M//2
    cy=N//2
    for i in range(M):
        for j in range(N):
            ed=np.sqrt((cx-i)*2+(cy-j)*2)
            if ed<=do:
                H[i,j]=1
            else:
                H[i,j]=0
    return H
def BLPF(D, D0, n=2):
    M, N = D.shape
    H = np.zeros_like(D, dtype=np.float64)
    cx, cy = M // 2, N // 2
    for i in range(M):
        for j in range(N):
            ed = np.sqrt((cx - i) ** 2 + (cy - j) ** 2)
            H[i, j] = 1 / (1 + (ed / D0) ** (2 * n))
    return H

def GLPF(D, D0):
    M, N = D.shape
    H = np.zeros_like(D, dtype=np.float64)
    cx, cy = M // 2, N // 2
    for i in range(M):
        for j in range(N):
            ed = np.sqrt((cx - i) ** 2 + (cy - j) ** 2)
            H[i, j] = np.exp(-(ed ** 2) / (2 * (D0 ** 2)))
    return H


img = cv2.imread('pic.jpg',cv2.IMREAD_GRAYSCALE)
# plt.imshow(img, cmap='gray')
# plt.title("Original Image")
# plt.show()
img = img.astype(np.float64)
P=padding(img)
C=centering(P)
D=DFT(img)
D0=100
H_ideal = ILPF(D, D0)
H_butter = BLPF(D, D0, n=2)
H_gauss = GLPF(D, D0)


D_ideal = D * H_ideal
D_butter = D * H_butter
D_gauss = D * H_gauss

plt.figure(figsize=(12, 8))

plt.subplot(1,4,1)
plt.imshow(np.log1p(np.abs(D)), cmap='gray')
plt.title("Original Spectrum")

plt.subplot(1,4,2)
plt.imshow(H_ideal, cmap='gray')
plt.title("ILPF")


plt.subplot(1,4,3)
plt.imshow(H_butter, cmap='gray')
plt.title("BLPF")

plt.subplot(1,4,4)
plt.imshow(H_gauss, cmap='gray')
plt.title("GLPF ")


plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3686405638.py:22: ComplexWarning: Casting complex values to real discards the imaginary part
#   ker[u,m]=np.exp(-(2j*math.pi*u*m)/size)
# /tmp/ipython-input-3686405638.py:40: RuntimeWarning: invalid value encountered in sqrt
#   ed=np.sqrt((cx-i)*2+(cy-j)*2)
